# %%
import csv

with open('../nba_player_data_20-21.csv', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=",", quotechar='"')
    next(reader, None)
    data_read = [row for row in reader]
    for i in range(0,3):
        print(data_read[i])
# Out:
# ['1', 'Precious Achiuwa', 'PF', '21', 'MIA', '61', '4', '12.1', '2', '3.7', '0.544', '0', '0', '0', '2', '3.7', '0.546', '0.544', '0.9', '1.8', '0.509', '1.2', '2.2', '3.4', '0.5', '0.3', '0.5', '0.7', '1.5', '5']
# ['2', 'Jaylen Adams', 'PG', '24', 'MIL', '7', '0', '2.6', '0.1', '1.1', '0.125', '0', '0.3', '0', '0.1', '0.9', '0.167', '0.125', '0', '0', '', '0', '0.4', '0.4', '0.3', '0', '0', '0', '0.1', '0.3']
# ['3', 'Steven Adams', 'C', '27', 'NOP', '58', '58', '27.7', '3.3', '5.3', '0.614', '0', '0.1', '0', '3.3', '5.3', '0.62', '0.614', '1', '2.3', '0.444', '3.7', '5.2', '8.9', '1.9', '0.9', '0.7', '1.3', '1.9', '7.6']

# %%
def get_player_name():
    with open('../nba_player_data_20-21.csv', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=",", quotechar='"')
        next(reader, None)
        data_read = [row for row in reader]
        for i in range(len(data_read)):
            #if data_read[i][1] == None:
            yield data_read[i][1]

# %%
for value in get_player_name(): 
    print(value)
# Out:
# Precious Achiuwa
# Jaylen Adams
# Steven Adams
# Bam Adebayo
# LaMarcus Aldridge
# LaMarcus Aldridge
# LaMarcus Aldridge
# Ty-Shon Alexander
# Nickeil Alexander-Walker
# Grayson Allen
# Jarrett Allen
# Jarrett Allen
# Jarrett Allen
# Al-Farouq Aminu
# Al-Farouq Aminu
# Al-Farouq Aminu
# Kyle Anderson
# Giannis Antetokounmpo
# Kostas Antetokounmpo
# Thanasis Antetokounmpo
# Carmelo Anthony
# Cole Anthony
# OG Anunoby
# Ryan Arcidiacono
# Trevor Ariza
# D.J. Augustin
# D.J. Augustin
# D.J. Augustin
# Deni Avdija
# Deandre Ayton
# Udoka Azubuike
# Dwayne Bacon
# Marvin Bagley III
# LaMelo Ball
# Lonzo Ball
# Mo Bamba
# Desmond Bane
# Harrison Barnes
# RJ Barrett
# Will Barton
# Keita Bates-Diop
# Nicolas Batum
# Aron Baynes
# Kent Bazemore
# Darius Bazley
# Bradley Beal
# Malik Beasley
# Jordan Bell
# Jordan Bell
# Jordan Bell
# DeAndre' Bembry
# Dāvis Bertāns
# Patrick Beverley
# Saddiq Bey
# Tyler Bey
# Khem Birch
# Khem Birch
# Khem Birch
# Goga Bitadze
# Bismack Biyombo
# ...

# %%
import pandas as pd
pd.read_csv('../nba_player_data_20-21.csv')
# Out:
#       Rk             Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa    PF   21  MIA  61   4  12.1  2.0   3.7  ...
# 1      2       Jaylen Adams    PG   24  MIL   7   0   2.6  0.1   1.1  ...
# 2      3       Steven Adams     C   27  NOP  58  58  27.7  3.3   5.3  ...
# 3      4        Bam Adebayo     C   23  MIA  64  64  33.5  7.1  12.5  ...
# 4      5  LaMarcus Aldridge     C   35  TOT  26  23  25.9  5.4  11.4  ...
# ..   ...                ...   ...  ...  ...  ..  ..   ...  ...   ...  ...
# 495  385     Cameron Oliver    SF   24  HOU   4   0  21.8  4.8   8.3  ...
# 496  386       Kelly Olynyk  C-PF   29  TOT  70  62  28.5  4.8  10.0  ...
# 497  386       Kelly Olynyk     C   29  MIA  43  38  26.9  3.8   8.7  ...
# 498  386       Kelly Olynyk    PF   29  HOU  27  24  31.1  6.5  11.9  ...
# 499  387           Miye Oni    SG   23  UTA  54   0   9.6  0.6   1.8  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...
